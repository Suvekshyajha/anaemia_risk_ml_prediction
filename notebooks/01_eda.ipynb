# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 100)
sns.set_style('whitegrid')

# %%
df = pd.read_stata('../data/raw/NPIR82FL.DTA', convert_categoricals=False)
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (14845, 5968)
#             caseid v000  v001  v002  v003  v004    v005  v006  v007  v008  \
# 0         1   1  2  NP8     1     1     2     1  916093    10  2078  2146
# 1         1   6  1  NP8     1     6     1     1  916093    10  2078  2146
# 2         1   8  2  NP8     1     8     2     1  916093    10  2078  2146
# 3         1   9  3  NP8     1     9     3     1  916093    10  2078  2146
# 4         1  11  4  NP8     1    11     4     1  916093    10  2078  2146
#
#    v008a  v009  v010  v011  v012  v013  v014  v015  v016  v017  v018  v019  \
# 0  28786    11  2048  1787    29     3     1     1    20  2077    11    70
# 1  28786     6  2045  1746    33     4     1     1    20  2077    11    70
# 2  28784     4  2045  1744    33     4     1     1    18  2077    11    70
# 3  28784     1  2044  1729    34     4     1     1    18  2077    11    70
# 4  28785     1  2055  1861    23     2     1     1    19  2077    11    70
#
#    v019a  v020  v021  v022  v023  v024  v025  v026  v027  v028  v029  v030  \
# 0      2     0     1     2     2     1     2   NaN     1   102   NaN   100
# 1      2     0     1     2     2     1     2   NaN     1   104   NaN   100
# 2      2     0     1     2     2     1     2   NaN     1   104   NaN   100
# 3      2     0     1     2     2     1     2   NaN     1   104   NaN   100
# 4      2     0     1     2     2     1     2   NaN     2   104   NaN   100
#
#    v031  v032  v034  v040  v042  v044  v045a  v045b  v045c  v046  v047  v048  \
# 0   NaN   NaN   1.0  1934     0     1      2      2      6     0     1   100
# 1   NaN   NaN   0.0  1934     1     0      2      2      2     0     1   100
# 2   NaN   NaN   3.0  1934     0     1      2      2      2     0     1   100
# 3   NaN   NaN   2.0  1934     1     0      2      2      2     0     1   100
# 4   NaN   NaN   3.0  1934     0     1      2      2      2     0     1   100
#
#    v101  v102  v103  v104  ...  s607ea_5  s607ea_6  s607eb_1  s607eb_2  \
# 0     1     2   NaN     2  ...       NaN       NaN       0.0       NaN
# 1     1     2   NaN     7  ...       NaN       NaN       NaN       NaN
# 2     1     2   NaN    95  ...       NaN       NaN       1.0       1.0
# 3     1     2   NaN     2  ...       NaN       NaN       0.0       NaN
# 4     1     2   NaN     6  ...       NaN       NaN       NaN       NaN
#
#    s607eb_3  s607eb_4  s607eb_5  s607eb_6  s607ec_1  s607ec_2  s607ec_3  \
# 0       NaN       NaN       NaN       NaN       0.0       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       NaN       0.0       0.0       NaN
# 3       NaN       NaN       NaN       NaN       0.0       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    s607ec_4  s607ec_5  s607ec_6  s607ed_1  s607ed_2  s607ed_3  s607ed_4  \
# 0       NaN       NaN       NaN       0.0       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       NaN       0.0       0.0       NaN       NaN
# 3       NaN       NaN       NaN       0.0       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    s607ed_5  s607ed_6  s607ex_1  s607ex_2  s607ex_3  s607ex_4  s607ex_5  \
# 0       NaN       NaN       0.0       NaN       NaN       NaN       NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2       NaN       NaN       0.0       0.0       NaN       NaN       NaN
# 3       NaN       NaN       0.0       NaN       NaN       NaN       NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#    s607ex_6  s607f_1  s607f_2  s607f_3  s607f_4  s607f_5  s607f_6  s607g_1  \
# 0       NaN      0.0      NaN      NaN      NaN      NaN      NaN      0.0
# 1       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2       NaN      NaN      NaN      NaN      NaN      NaN      NaN      0.0
# 3       NaN      1.0      NaN      NaN      NaN      NaN      NaN      0.0
# 4       NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    s607g_2  s607g_3  s607g_4  s607g_5  s607g_6  s615f_1  s615f_2  s615f_3  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      0.0      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    s615f_4  s615f_5  s615f_6  s631o_1  s631o_2  s631o_3  s631o_4  s631o_5  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      0.0      0.0      NaN      NaN      NaN
# 3      NaN      NaN      NaN      0.0      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    s631o_6
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#
# [5 rows x 5968 columns]

# %%
df.info(verbose=False)  # quick dtype/memory overview
df.columns.tolist()[:30]  # peek at first 30 variable names
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14845 entries, 0 to 14844
# Columns: 5968 entries, caseid to s631o_6
# dtypes: float64(5632), int16(22), int32(3), int8(307), object(4)
# memory usage: 643.5+ MB
# ['caseid',
#  'v000',
#  'v001',
#  'v002',
#  'v003',
#  'v004',
#  'v005',
#  'v006',
#  'v007',
#  'v008',
#  'v008a',
#  'v009',
#  'v010',
#  'v011',
#  'v012',
#  'v013',
#  'v014',
#  'v015',
#  'v016',
#  'v017',
#  'v018',
#  'v019',
#  'v019a',
#  'v020',
#  'v021',
#  'v022',
#  'v023',
#  'v024',
#  'v025',
#  'v026']

# %%
df['v025'].value_counts(normalize=True) * 100
# Out:
# v025
# 1    54.018188
# 2    45.981812
# Name: proportion, dtype: float64

# %%
rural_df = df[df['v025'] == 2].copy()
print("Rural sample shape:", rural_df.shape)
# Out:
# Rural sample shape: (6826, 5968)

# %%
#top 20 missing variables
missing_pct = df.isnull().mean().sort_values(ascending=False) * 100
print(missing_pct.head(20))
